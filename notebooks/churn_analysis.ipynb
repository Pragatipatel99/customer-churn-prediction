# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.svm import SVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, roc_auc_score

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.5

# %%
df = pd.read_csv("../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
#  17  PaymentMethod     7043 non-null   str
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   str
#  20  Churn             7043 non-null   str
# dtypes: float64(1), int64(2), str(18)
# memory usage: 1.1 MB

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df["Churn"].value_counts(normalize=True) * 100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
sns.countplot(x="Churn", data=df)

plt.title("Customer Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Number of Customers")

plt.show()

# %%
sns.countplot(x="Churn", data=df)

plt.title("Customer Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Number of Customers")

plt.show()

# %%
df[["tenure", "MonthlyCharges"]].describe()
# Out:
#             tenure  MonthlyCharges
# count  7043.000000     7043.000000
# mean     32.371149       64.761692
# std      24.559481       30.090047
# min       0.000000       18.250000
# 25%       9.000000       35.500000
# 50%      29.000000       70.350000
# 75%      55.000000       89.850000
# max      72.000000      118.750000

# %%
df[["tenure", "MonthlyCharges"]].hist(figsize=(10, 5))

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))

sns.boxplot(data=df[["tenure", "MonthlyCharges"]])

plt.title("Box Plot of Numerical Features")
plt.show()

# %%
sns.countplot(x="Contract", data=df)

plt.title("Customer Distribution by Contract Type")
plt.xlabel("Contract Type")
plt.ylabel("Number of Customers")

plt.xticks(rotation=15)
plt.show()

# %%
sns.countplot(x="InternetService", data=df)

plt.title("Customer Distribution by Internet Service")
plt.xlabel("Internet Service")
plt.ylabel("Number of Customers")

plt.show()

# %%
contract_churn = pd.crosstab(
    df["Contract"],
    df["Churn"],
    normalize="index"
) * 100

contract_churn
# Out:
# Churn                  No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.730482  11.269518
# Two year        97.168142   2.831858

# %%
contract_churn["Yes"].plot(kind="bar")

plt.title("Churn Rate by Contract Type")
plt.xlabel("Contract Type")
plt.ylabel("Churn Rate (%)")
plt.xticks(rotation=0)

plt.show()

# %%
internet_churn = pd.crosstab(
    df["InternetService"],
    df["Churn"],
    normalize="index"
) * 100

internet_churn
# Out:
# Churn                   No        Yes
# InternetService
# DSL              81.040892  18.959108
# Fiber optic      58.107235  41.892765
# No               92.595020   7.404980

# %%
internet_churn["Yes"].plot(kind="bar")

plt.title("Churn Rate by Internet Service")
plt.xlabel("Internet Service")
plt.ylabel("Churn Rate (%)")
plt.xticks(rotation=0)

plt.show()

# %%
payment_churn = pd.crosstab(
    df["PaymentMethod"],
    df["Churn"],
    normalize="index"
) * 100

payment_churn
# Out:
# Churn                             No        Yes
# PaymentMethod
# Bank transfer (automatic)  83.290155  16.709845
# Credit card (automatic)    84.756899  15.243101
# Electronic check           54.714588  45.285412
# Mailed check               80.893300  19.106700

# %%
payment_churn["Yes"].plot(kind="bar")

plt.title("Churn Rate by Payment Method")
plt.xlabel("Payment Method")
plt.ylabel("Churn Rate (%)")
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
numeric_df = df[["tenure", "MonthlyCharges"]]

# %%
correlation = numeric_df.corr()

correlation
# Out:
#                 tenure  MonthlyCharges
# tenure          1.0000          0.2479
# MonthlyCharges  0.2479          1.0000

# %%
plt.figure(figsize=(6, 4))

sns.heatmap(
    correlation,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")

plt.show()

# %%
df["TotalCharges"].dtype
# Out:
# dtype('O')

# %%
df["TotalCharges"] = pd.to_numeric(
    df["TotalCharges"],
    errors="coerce"
)

# %%
df["TotalCharges"].dtype
# Out:
# dtype('float64')

# %%
df["TotalCharges"].isnull().sum()
# Out:
# np.int64(11)

# %%
df["TotalCharges"].dtype
# Out:
# dtype('float64')

# %%
df["TotalCharges"].isnull().sum()
# Out:
# np.int64(11)

# %%
df[df["TotalCharges"].isnull()][["tenure", "MonthlyCharges", "TotalCharges", "Churn"]]
# Out:
#       tenure  MonthlyCharges  TotalCharges Churn
# 488        0           52.55           NaN    No
# 753        0           20.25           NaN    No
# 936        0           80.85           NaN    No
# 1082       0           25.75           NaN    No
# 1340       0           56.05           NaN    No
# 3331       0           19.85           NaN    No
# 3826       0           25.35           NaN    No
# 4380       0           20.00           NaN    No
# 5218       0           19.70           NaN    No
# 6670       0           73.35           NaN    No
# 6754       0           61.90           NaN    No

# %%
median_total_charges = df["TotalCharges"].median()

median_total_charges
# Out:
# np.float64(1397.475)

# %%
df["TotalCharges"] = df["TotalCharges"].fillna(median_total_charges)

# %%
df["TotalCharges"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df["tenure_group"] = pd.cut(
    df["tenure"],
    bins=[-1, 12, 48, 72],
    labels=["0-12 months", "13-48 months", "49+ months"]
)

df["monthly_charge_group"] = pd.cut(
    df["MonthlyCharges"],
    bins=[-1, 40, 80, float("inf")],
    labels=["Low", "Medium", "High"]
)

df["has_dependents"] = df["Dependents"].map({
    "Yes": 1,
    "No": 0
})

service_columns = [
    "OnlineSecurity",
    "OnlineBackup",
    "DeviceProtection",
    "TechSupport",
    "StreamingTV",
    "StreamingMovies"
]

df["total_services"] = (
    df[service_columns]
    .apply(lambda row: (row == "Yes").sum(), axis=1)
)

df.drop("customerID", axis=1, inplace=True)

print(df.shape)
# Out:
# (7043, 24)

# %%
df[["tenure", "tenure_group"]].head(10)
# Out:
#    tenure  tenure_group
# 0       1   0-12 months
# 1      34  13-48 months
# 2       2   0-12 months
# 3      45  13-48 months
# 4       2   0-12 months
# 5       8   0-12 months
# 6      22  13-48 months
# 7      10   0-12 months
# 8      28  13-48 months
# 9      62    49+ months

# %%
X = df.drop("Churn", axis=1)

y = df["Churn"].map({
    "Yes": 1,
    "No": 0
})

print(X.shape)
print(y.shape)
# Out:
# (7043, 23)
# (7043,)

# %%
pd.crosstab(
    df["tenure_group"],
    df["Churn"],
    normalize="index"
) * 100
# Out:
# Churn                No        Yes
# tenure_group
# 0-12 months   52.561757  47.438243
# 13-48 months  76.355997  23.644003
# 49+ months    90.486824   9.513176

# %%
df["monthly_charge_group"] = pd.cut(
    df["MonthlyCharges"],
    bins=[-1, 40, 80, float("inf")],
    labels=["Low", "Medium", "High"]
)

# %%
df[["MonthlyCharges", "monthly_charge_group"]].head(10)
# Out:
#    MonthlyCharges monthly_charge_group
# 0           29.85                  Low
# 1           56.95               Medium
# 2           53.85               Medium
# 3           42.30               Medium
# 4           70.70               Medium
# 5           99.65                 High
# 6           89.10                 High
# 7           29.75                  Low
# 8          104.80                 High
# 9           56.15               Medium

# %%
pd.crosstab(
    df["monthly_charge_group"],
    df["Churn"],
    normalize="index"
) * 100
# Out:
# Churn                        No        Yes
# monthly_charge_group
# Low                   88.356910  11.643090
# Medium                70.500197  29.499803
# High                  66.016504  33.983496

# %%
pd.crosstab(
    df["monthly_charge_group"],
    df["Churn"],
    normalize="index"
) * 100
# Out:
# Churn                        No        Yes
# monthly_charge_group
# Low                   88.356910  11.643090
# Medium                70.500197  29.499803
# High                  66.016504  33.983496

# %%
df["has_dependents"] = df["Dependents"].map({
    "Yes": 1,
    "No": 0
})

# %%
df[["Dependents", "has_dependents"]].head(10)
# Out:
#   Dependents  has_dependents
# 0         No               0
# 1         No               0
# 2         No               0
# 3         No               0
# 4         No               0
# 5         No               0
# 6        Yes               1
# 7         No               0
# 8         No               0
# 9        Yes               1

# %%
service_columns = [
    "OnlineSecurity",
    "OnlineBackup",
    "DeviceProtection",
    "TechSupport",
    "StreamingTV",
    "StreamingMovies"
]

# %%
df["total_services"] = (
    df[service_columns]
    .apply(lambda row: (row == "Yes").sum(), axis=1)
)

# %%
df[service_columns + ["total_services"]].head(10)
# Out:
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0             No          Yes               No          No          No
# 1            Yes           No              Yes          No          No
# 2            Yes          Yes               No          No          No
# 3            Yes           No              Yes         Yes          No
# 4             No           No               No          No          No
# 5             No           No              Yes          No         Yes
# 6             No          Yes               No          No         Yes
# 7            Yes           No               No          No          No
# 8             No           No              Yes         Yes         Yes
# 9            Yes          Yes               No          No          No
#
#   StreamingMovies  total_services
# 0              No               1
# 1              No               2
# 2              No               2
# 3              No               3
# 4              No               0
# 5             Yes               3
# 6              No               2
# 7              No               1
# 8             Yes               4
# 9              No               2

# %%
df.drop("customerID", axis=1, inplace=True, errors="ignore")

# %%
print(df.columns.tolist())
# Out:
# ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn', 'tenure_group', 'monthly_charge_group', 'has_dependents', 'total_services']

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#          Contract PaperlessBilling              PaymentMethod MonthlyCharges  \
# 0  Month-to-month              Yes           Electronic check          29.85
# 1        One year               No               Mailed check          56.95
# 2  Month-to-month              Yes               Mailed check          53.85
# 3        One year               No  Bank transfer (automatic)          42.30
# 4  Month-to-month              Yes           Electronic check          70.70
#
#   TotalCharges Churn  tenure_group  monthly_charge_group  has_dependents  \
# 0        29.85    No   0-12 months                   Low               0
# 1      1889.50    No  13-48 months                Medium               0
# 2       108.15   Yes   0-12 months                Medium               0
# 3      1840.75    No  13-48 months                Medium               0
# 4       151.65   Yes   0-12 months                Medium               0
#
#   total_services
# 0              1
# 1              2
# 2              2
# 3              3
# 4              0
#
# [5 rows x 24 columns]

# %%
X = df.drop("Churn", axis=1)
y = df["Churn"]

# %%
X.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# 0              No  Month-to-month              Yes           Electronic check
# 1              No        One year               No               Mailed check
# 2              No  Month-to-month              Yes               Mailed check
# 3              No        One year               No  Bank transfer (automatic)
# 4              No  Month-to-month              Yes           Electronic check
#
#   MonthlyCharges TotalCharges  tenure_group  monthly_charge_group  \
# 0          29.85        29.85   0-12 months                   Low
# 1          56.95      1889.50  13-48 months                Medium
# 2          53.85       108.15   0-12 months                Medium
# 3          42.30      1840.75  13-48 months                Medium
# 4          70.70       151.65   0-12 months                Medium
#
#    has_dependents total_services
# 0               0              1
# 1               0              2
# 2               0              2
# 3               0              3
# 4               0              0
#
# [5 rows x 23 columns]

# %%
y.head()
# Out:
# 0     No
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# Name: Churn, dtype: str

# %%
y = y.map({
    "Yes": 1,
    "No": 0
})

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Churn, dtype: int64

# %%
categorical_columns = X.select_dtypes(
    include=["object", "string", "category"]
).columns

numerical_columns = X.select_dtypes(
    include=["int64", "float64"]
).columns

print("Categorical columns:")
print(categorical_columns)

print("\nNumerical columns:")
print(numerical_columns)
# Out:
# Categorical columns:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'tenure_group',
#        'monthly_charge_group'],
#       dtype='object')
#
# Numerical columns:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges',
#        'has_dependents', 'total_services'],
#       dtype='object')

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numerical_columns),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_columns)
    ]
)

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num', StandardScaler(),
#                                  Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges',
#        'has_dependents', 'total_services'],
#       dtype='str')),
#                                 ('cat', OneHotEncoder(handle_unknown='ignore'),
#                                  Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'tenure_group',
#        'monthly_charge_group'],
#       dtype='str'))])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (5634, 23)
# X_test: (1409, 23)
# y_train: (5634,)
# y_test: (1409,)

# %%
X_train_processed = preprocessor.fit_transform(X_train)
X_test_processed = preprocessor.transform(X_test)

# %%
print("Training data shape:", X_train_processed.shape)
print("Testing data shape:", X_test_processed.shape)
# Out:
# Training data shape: (5634, 53)
# Testing data shape: (1409, 53)

# %%
lr_model = LogisticRegression(
    max_iter=1000,
    random_state=42
)

# %%
lr_model.fit(X_train_processed, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
y_pred_lr = lr_model.predict(X_test_processed)

# %%
y_pred_lr[:10]
# Out:
# array([0, 1, 0, 0, 0, 1, 0, 0, 0, 0])

# %%
print("Accuracy :", accuracy_score(y_test, y_pred_lr))
print("Precision:", precision_score(y_test, y_pred_lr))
print("Recall   :", recall_score(y_test, y_pred_lr))
print("F1 Score :", f1_score(y_test, y_pred_lr))
# Out:
# Accuracy : 0.7991483321504613
# Precision: 0.6501650165016502
# Recall   : 0.5267379679144385
# F1 Score : 0.5819793205317577

# %%
y_prob_lr = lr_model.predict_proba(X_test_processed)[:, 1]

# %%
auc_lr = roc_auc_score(y_test, y_prob_lr)

print("ROC-AUC:", auc_lr)
# Out:
# ROC-AUC: 0.8414218915497689

# %%
svm_model = CalibratedClassifierCV(
    SVC(),
    ensemble=False
)

# %%
svm_model.fit(X_train_processed, y_train)
# Out:
# CalibratedClassifierCV(ensemble=False, estimator=SVC())

# %%
y_pred_svm = svm_model.predict(X_test_processed)

# %%
y_prob_svm = svm_model.predict_proba(X_test_processed)[:, 1]

# %%
auc_svm = roc_auc_score(y_test, y_prob_svm)

print("ROC-AUC:", auc_svm)
# Out:
# ROC-AUC: 0.7965382727531065

# %%
rf_model = RandomForestClassifier(
    n_estimators=200,
    random_state=42,
    class_weight="balanced"
)

# %%
rf_model.fit(X_train_processed, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200,
#                        random_state=42)

# %%
y_pred_svm = svm_model.predict(X_test_processed)

# %%
y_pred_svm[:10]
# Out:
# array([0, 1, 0, 0, 0, 1, 0, 0, 0, 0])

# %%
accuracy_svm = accuracy_score(y_test, y_pred_svm)
precision_svm = precision_score(y_test, y_pred_svm)
recall_svm = recall_score(y_test, y_pred_svm)
f1_svm = f1_score(y_test, y_pred_svm)
auc_svm = roc_auc_score(y_test, y_prob_svm)

print("SVM")
print("Accuracy :", accuracy_svm)
print("Precision:", precision_svm)
print("Recall   :", recall_svm)
print("F1 Score :", f1_svm)
print("ROC-AUC  :", auc_svm)
# Out:
# SVM
# Accuracy : 0.7877927608232789
# Precision: 0.6530612244897959
# Recall   : 0.42780748663101603
# F1 Score : 0.5169628432956381
# ROC-AUC  : 0.7965382727531065

# %%
y_prob_rf = rf_model.predict_proba(X_test_processed)[:, 1]

# %%
results.append({
    "Model": "SVM",
    "Accuracy": accuracy_svm,
    "Precision": precision_svm,
    "Recall": recall_svm,
    "F1": f1_svm,
    "ROC-AUC": auc_svm
})

# %%
y_prob_rf = rf_model.predict_proba(X_test_processed)[:, 1]

# %%
auc_rf = roc_auc_score(y_test, y_prob_rf)

print("ROC-AUC:", auc_rf)
# Out:
# ROC-AUC: 0.8207199875997829

# %%
lgbm_model = LGBMClassifier(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=5,
    random_state=42,
    verbosity=-1
)

# %%
lgbm_model.fit(X_train_processed, y_train)
# Out:
# LGBMClassifier(learning_rate=0.05, max_depth=5, n_estimators=200,
#                random_state=42, verbosity=-1)

# %%
y_pred_lgbm = lgbm_model.predict(X_test_processed)

# %%
y_pred_lgbm[:10]
# Out:
# array([0, 1, 0, 0, 0, 1, 1, 0, 0, 0])

# %%
accuracy_lgbm = accuracy_score(y_test, y_pred_lgbm)
precision_lgbm = precision_score(y_test, y_pred_lgbm)
recall_lgbm = recall_score(y_test, y_pred_lgbm)
f1_lgbm = f1_score(y_test, y_pred_lgbm)

print("Accuracy :", accuracy_lgbm)
print("Precision:", precision_lgbm)
print("Recall   :", recall_lgbm)
print("F1 Score :", f1_lgbm)
# Out:
# Accuracy : 0.7963094393186657
# Precision: 0.6426229508196721
# Recall   : 0.5240641711229946
# F1 Score : 0.5773195876288659

# %%
y_prob_lgbm = lgbm_model.predict_proba(X_test_processed)[:, 1]

auc_lgbm = roc_auc_score(y_test, y_prob_lgbm)

print("ROC-AUC:", auc_lgbm)
# Out:
# ROC-AUC: 0.8393125629698519

# %%
results = [
    {
        "Model": "Logistic Regression",
        "Accuracy": accuracy_score(y_test, y_pred_lr),
        "Precision": precision_score(y_test, y_pred_lr),
        "Recall": recall_score(y_test, y_pred_lr),
        "F1": f1_score(y_test, y_pred_lr),
        "ROC-AUC": roc_auc_score(
            y_test,
            lr_model.predict_proba(X_test_processed)[:, 1]
        )
    },
    {
        "Model": "SVM",
        "Accuracy": accuracy_score(y_test, y_pred_svm),
        "Precision": precision_score(y_test, y_pred_svm),
        "Recall": recall_score(y_test, y_pred_svm),
        "F1": f1_score(y_test, y_pred_svm),
        "ROC-AUC": roc_auc_score(
            y_test,
            svm_model.predict_proba(X_test_processed)[:, 1]
        )
    },
    {
        "Model": "Random Forest",
        "Accuracy": accuracy_score(y_test, y_pred_rf),
        "Precision": precision_score(y_test, y_pred_rf),
        "Recall": recall_score(y_test, y_pred_rf),
        "F1": f1_score(y_test, y_pred_rf),
        "ROC-AUC": roc_auc_score(
            y_test,
            rf_model.predict_proba(X_test_processed)[:, 1]
        )
    },
    {
        "Model": "LightGBM",
        "Accuracy": accuracy_score(y_test, y_pred_lgbm),
        "Precision": precision_score(y_test, y_pred_lgbm),
        "Recall": recall_score(y_test, y_pred_lgbm),
        "F1": f1_score(y_test, y_pred_lgbm),
        "ROC-AUC": roc_auc_score(
            y_test,
            lgbm_model.predict_proba(X_test_processed)[:, 1]
        )
    }
]

# %%
results_df = pd.DataFrame(results)
results_df
# Out:
#                  Model  Accuracy  Precision    Recall        F1   ROC-AUC
# 0  Logistic Regression  0.799148   0.650165  0.526738  0.581979  0.841422
# 1                  SVM  0.787793   0.653061  0.427807  0.516963  0.796538
# 2        Random Forest  0.767921   0.554524  0.639037  0.593789  0.820720
# 3             LightGBM  0.796309   0.642623  0.524064  0.577320  0.839313

# %%
best_model_row = results_df.loc[
    results_df["ROC-AUC"].idxmax()
]

best_model_row
# Out:
# Model        Logistic Regression
# Accuracy                0.799148
# Precision               0.650165
# Recall                  0.526738
# F1                      0.581979
# ROC-AUC                 0.841422
# Name: 0, dtype: object

# %%
param_grid = {
    "n_estimators": [100, 200],
    "learning_rate": [0.03, 0.05, 0.1],
    "max_depth": [3, 5, 7],
    "num_leaves": [15, 31]
}

# %%
grid_search = GridSearchCV(
    estimator=LGBMClassifier(
        random_state=42,
        verbosity=-1
    ),
    param_grid=param_grid,
    scoring="roc_auc",
    cv=5,
    n_jobs=-1
)

# %%
grid_search.fit(X_train_processed, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LGBMClassifier(random_state=42, verbosity=-1),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.03, 0.05, 0.1],
#                          'max_depth': [3, 5, 7], 'n_estimators': [100, 200],
#                          'num_leaves': [15, 31]},
#              scoring='roc_auc')

# %%
print("Grid search status:")
print(grid_search)
# Out:
# Grid search status:
# GridSearchCV(cv=5, estimator=LGBMClassifier(random_state=42, verbosity=-1),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.03, 0.05, 0.1],
#                          'max_depth': [3, 5, 7], 'n_estimators': [100, 200],
#                          'num_leaves': [15, 31]},
#              scoring='roc_auc')

# %%
print("Best score:", getattr(grid_search, "best_score_", "NOT COMPLETED"))
# Out:
# Best score: 0.8481323748042684

# %%
print("Best CV ROC-AUC:")
print(grid_search.best_score_)
# Out:
# Best CV ROC-AUC:
# 0.8481323748042684

# %%
best_lgbm = grid_search.best_estimator_

# %%
y_pred_final = best_lgbm.predict(X_test_processed)

# %%
accuracy_final = accuracy_score(y_test, y_pred_final)
precision_final = precision_score(y_test, y_pred_final)
recall_final = recall_score(y_test, y_pred_final)
f1_final = f1_score(y_test, y_pred_final)

# %%
y_prob_final = best_lgbm.predict_proba(X_test_processed)[:, 1]

auc_final = roc_auc_score(y_test, y_prob_final)

# %%
print("Final Tuned LightGBM Performance")
print("--------------------------------")
print("Accuracy :", accuracy_final)
print("Precision:", precision_final)
print("Recall   :", recall_final)
print("F1 Score :", f1_final)
print("ROC-AUC  :", auc_final)
# Out:
# Final Tuned LightGBM Performance
# --------------------------------
# Accuracy : 0.8055358410220014
# Precision: 0.6736111111111112
# Recall   : 0.5187165775401069
# F1 Score : 0.5861027190332326
# ROC-AUC  : 0.846440104368493

# %%
cm = confusion_matrix(y_test, y_pred_final)

print(cm)
# Out:
# [[941  94]
#  [180 194]]

# %%
plt.figure(figsize=(6, 4))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Churn", "Churn"],
    yticklabels=["No Churn", "Churn"]
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Tuned LightGBM")

plt.show()

# %%
print(
    classification_report(
        y_test,
        y_pred_final,
        target_names=["No Churn", "Churn"]
    )
)
# Out:
#               precision    recall  f1-score   support
#
#     No Churn       0.84      0.91      0.87      1035
#        Churn       0.67      0.52      0.59       374
#
#     accuracy                           0.81      1409
#    macro avg       0.76      0.71      0.73      1409
# weighted avg       0.80      0.81      0.80      1409

# %%
y_prob_final
# Out:
# array([0.03512594, 0.73361607, 0.07233318, ..., 0.1393245 , 0.01911258,
#        0.00976737], shape=(1409,))

# %%
fpr, tpr, thresholds = roc_curve(
    y_test,
    y_prob_final
)

# %%
plt.figure(figsize=(7, 5))

plt.plot(
    fpr,
    tpr,
    label=f"LightGBM (AUC = {auc_final:.3f})"
)

plt.plot(
    [0, 1],
    [0, 1],
    linestyle="--",
    label="Random Guess"
)

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Tuned LightGBM")
plt.legend()

plt.show()

# %%
feature_importance = best_lgbm.feature_importances_

print(len(feature_importance))
# Out:
# 53

# %%
feature_importance = best_lgbm.feature_importances_
print(len(feature_importance))
# Out:
# 53

# %%
feature_names = preprocessor.get_feature_names_out()

# %%
print(len(feature_names))
# Out:
# 53

# %%
len(feature_importance)
# Out:
# 53

# %%
importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Importance": feature_importance
})

# %%
importance_df = importance_df.sort_values(
    by="Importance",
    ascending=False
)

# %%
importance_df.head(10)
# Out:
#                                 Feature  Importance
# 1                           num__tenure         142
# 2                   num__MonthlyCharges         131
# 3                     num__TotalCharges          79
# 20               cat__OnlineSecurity_No          33
# 41             cat__PaperlessBilling_No          32
# 38         cat__Contract_Month-to-month          31
# 45  cat__PaymentMethod_Electronic check          31
# 40               cat__Contract_Two year          29
# 39               cat__Contract_One year          26
# 14                cat__MultipleLines_No          25

# %%
top10 = importance_df.head(10)

plt.figure(figsize=(10, 6))

plt.barh(
    top10["Feature"][::-1],
    top10["Importance"][::-1]
)

plt.xlabel("Feature Importance")
plt.ylabel("Feature")
plt.title("Top 10 Features Driving Customer Churn")

plt.tight_layout()
plt.show()

# %%
feature_names = preprocessor.get_feature_names_out()

importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Importance": best_lgbm.feature_importances_
})

# %%
importance_df = importance_df.sort_values(
    by="Importance",
    ascending=False
)

# %%
importance_df.head(10)
# Out:
#                                 Feature  Importance
# 1                           num__tenure         142
# 2                   num__MonthlyCharges         131
# 3                     num__TotalCharges          79
# 20               cat__OnlineSecurity_No          33
# 41             cat__PaperlessBilling_No          32
# 38         cat__Contract_Month-to-month          31
# 45  cat__PaymentMethod_Electronic check          31
# 40               cat__Contract_Two year          29
# 39               cat__Contract_One year          26
# 14                cat__MultipleLines_No          25

# %%
top10 = importance_df.head(10)

plt.figure(figsize=(10, 6))

plt.barh(
    top10["Feature"][::-1],
    top10["Importance"][::-1]
)

plt.xlabel("Feature Importance")
plt.ylabel("Feature")
plt.title("Top 10 Features Driving Customer Churn")

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import sys

print("Pandas:", pd.__version__)
print("Python:", sys.executable)
# Out:
# Pandas: 2.3.3
# Python: C:\Users\praga\anaconda3\envs\churn_env\python.exe

# %%
import joblib

best_lgbm = joblib.load("../models/churn_model.pkl")

print("Model loaded successfully")
print("Model expects:", best_lgbm.n_features_in_)
# Out:
# Model loaded successfully
# Model expects: 53
# C:\Users\praga\anaconda3\envs\churn_env\lib\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.9.0 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
preprocessor.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 preprocessor.fit(X_train)
#
# NameError: name 'X_train' is not defined
